# %% [markdown]
# # Entendimiento inicial de los datos

# %% [markdown]
# ### Carga y limpieza de Datos

# %%
# Importación de librerías
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as stats
from scipy.stats import chi2_contingency
import re

# Función para convertir string a horas
def to_hours(time_str):
    if pd.isna(time_str):
        return None
    match = re.match(r"(?:(\d+)h)?(?:(\d+)m)?(?:(\d+)s)?", time_str)
    if not match:
        return None
    h, m, s = match.groups(default="0")
    total_hours = int(h) + int(m)/60 + int(s)/3600
    return total_hours
# transformación columnas a tipo entero
def convertir_string(cast_columns_int,df):
    for i in cast_columns_int:
        df[i]=(
        pd.to_numeric(df[i], errors="coerce")
          .round()
          .astype("Int64")
        )
# transformación columnas a tipo fecha
def convertir_date(cast_columns_date,df):
    for i in cast_columns_date:
        df[i]=(
        pd.to_datetime(df[i], errors="coerce")
        )
# limpieza columnas tipo string (object) 
def eliminar_espacios(columns_object,df):
    df[columns_object]=df[columns_object].apply(lambda x: x.str.strip())

# %%
# carga fuente insumo
users_df = pd.read_csv("data/users.csv")
declarations_df = pd.read_csv("data/declarations.csv")
projects_computed_df = pd.read_csv("data/projects_computed.csv")
projects_df = pd.read_csv("data/projects.csv")
subscriptions_df = pd.read_csv("data/subscriptions.csv")
tasks_computed_df = pd.read_csv("data/tasks_computed.csv")
tasks_df = pd.read_csv("data/tasks.csv")
teams_df = pd.read_csv("data/teams.csv")

# convercion columnas de tiempo
cast_columns_date = ["created_at","deleted_at"]
convertir_date(cast_columns_date,users_df)
cast_columns_date = ["created_at"]
convertir_date(cast_columns_date,projects_computed_df)
cast_columns_date = ["subscribe_at","disabled_at","trial_start_at","trial_end_at"]
convertir_date(cast_columns_date,subscriptions_df)
cast_columns_date = ["created_at"]
convertir_date(cast_columns_date,tasks_computed_df)
cast_columns_date = ["created_at","deleted_at"]
convertir_date(cast_columns_date,teams_df)
cast_columns_date = ["created_at","date"]
convertir_date(cast_columns_date,declarations_df)
cast_columns_date = ["created_at"]
convertir_date(cast_columns_date,tasks_df)
cast_columns_date = ["created_at"]
convertir_date(cast_columns_date,projects_df)

#creacion tabla empleados
empleados_df = pd.merge(
    users_df, 
    teams_df, 
    how='left',
    left_on='team_id',
    right_on='id'
)
empleados_df = empleados_df.rename(columns={
    'id_x': 'empleado_id',
    'created_at_x': 'creacion_empleado_grizzly',
    'deleted_at_x': 'eliminacion_empleado_grizzly',
    'created_at_y': 'creacion_team_grizzly',
    'deleted_at_y': 'eliminacion_grizzly'
})
empleados_df = empleados_df.drop(columns=['id_y']).drop_duplicates()
# creacion tabla tareas
tareas_df = pd.merge(
    tasks_df, 
    tasks_computed_df, 
    how='left',
    left_on='id',
    right_on='id'
)
tareas_df = tareas_df.rename(columns={
    'id': 'tarea_id',
    'created_at_x': 'creacion_tarea_grizzly',
    'is_container_x': 'is_subtarea',
    'parent_id_x':'parent_id',
    'project_id_x': 'proyecto_id',
    'created_at_y': 'creacion_tarea_date',
    'planned_duration':'duracion_planeada_tarea',
    'elapsed_duration':'duracion_trascurrida_tarea'
})
tareas_df = tareas_df.drop(columns=['is_container_y','parent_id_y','project_id_y','creacion_tarea_date']).drop_duplicates()
tareas_df.sample(3)
#creacion tabla proyectos
proyectos_df = pd.merge(
    projects_df, 
    projects_computed_df, 
    how='left',
    left_on='id',
    right_on='id'
)

proyectos_df = proyectos_df.rename(columns={
    'id': 'proyecto_id',
    'created_at_x': 'creacion_proyecto_grizzly',
    'team_id_x':'team_id',
    'created_at_y': 'creacion_proyecto_date',
    'team_id_y':'team_id_2',
    'planned_duration':'duracion_planeada_projecto',
    'elapsed_duration':'duracion_trascurrida_projecto'
}).drop_duplicates()
proyectos_df = proyectos_df.drop(columns=['team_id_2','creacion_proyecto_date']).drop_duplicates()
proyectos_df.sample(3)
equipos_df = pd.merge(
    teams_df, 
    subscriptions_df, 
    how='left',
    left_on='id',
    right_on='team_id'
)
equipos_df = equipos_df.drop(columns=['team_id'])
equipos_df = equipos_df.rename(columns={
    'id': 'team_id',
    'deleted_at': 'eliminacion_team_grizzly',
    'created_at': 'creacion_team_grizzly',
    'subscribe_at':'fecha_subcripcion_empresa_grizzly',
    'disabled_at': 'fecha_deshabilitacion_empresa_grizzly',
    'status':'estado',
    'offer':'oferta',
    'trial_start_at':'inicio_prueba_en',
    'trial_end_at':'finalizacion_prueba_en'
}).drop_duplicates()
tareas_empleados_df = pd.merge(
    tareas_df, 
    declarations_df, 
    how='left',
    left_on='tarea_id',
    right_on='task_id'
)
tareas_empleados_df = tareas_empleados_df.rename(columns={
    'duration': 'duracion_tarea',
    'source': 'fuente',
    'user_id':'empleado_id',
    'id':'id_registro_declaracion',
    'created_at':'fecha_registro_grizzly_empleado',
    'date': 'fecha_tarea_empleado'
})
tareas_empleados_df = tareas_empleados_df.drop(columns=['task_id']).drop_duplicates()
tareas_empleados_projectos_df = pd.merge(
    tareas_empleados_df, 
    proyectos_df, 
    how='left',
    left_on='proyecto_id',
    right_on='proyecto_id'
)
maestra_df = pd.merge(
    tareas_empleados_projectos_df, 
    equipos_df, 
    how='left',
    left_on='team_id',
    right_on='team_id'
)
pd.options.display.float_format = '{:.2f}'.format
# Se convierte la columna duracion tarea a tiempo en horas
maestra_df["duracion_tarea"] = (maestra_df["duracion_tarea"] / 3_600_000_000_000)
# se convierte las columnas de duracion en formato string a horas
maestra_df['duracion_planeada_tarea']= maestra_df["duracion_planeada_tarea"].apply(to_hours)
maestra_df['duracion_trascurrida_tarea']= maestra_df["duracion_trascurrida_tarea"].apply(to_hours)
maestra_df['duracion_planeada_projecto']= maestra_df["duracion_planeada_projecto"].apply(to_hours)
maestra_df['duracion_trascurrida_projecto']= maestra_df["duracion_trascurrida_projecto"].apply(to_hours)
#creacion columna duracion_dias_team
maestra_df['duracion_meses_team'] = ((maestra_df['eliminacion_team_grizzly'] - maestra_df['creacion_team_grizzly']).dt.days/30).round()

# df=maestra_df[(maestra_df["proyecto_id"]=="cddd00a8-691c-412b-8dbf-13d2599096f4") & (tareas_empleados_projectos_df["tarea_id"]=="00015d04-66ca-41f0-8a9a-40dc49fd029d")].sort_values(by='fecha_tarea_empleado')
# df["duracion_tarea"]

# %% [markdown]
# La columna oferta indica el tipo de seguimiento que se desea hacer a los proyectos. Las categorias son:
# - time: Registro detallado del tiempo trabajado por empleados
# - budget: Control y seguimiento de presupuestos de proyectos
# - fremium: Versión gratuita o de prueba
# Como se quiere es realizar un seguimiento del tiempo en las actividades de los empleados, relacionadas a proyectos, se filtra dicha columna con time.

# %%
maestra_df=maestra_df[maestra_df["oferta"]=="time"]

# %% [markdown]
# # Analisis univariado

# %% [markdown]
# ## fecha_tarea_empleado

# %%
# Agrupar por fecha y contar tareas
tareas_por_fecha = maestra_df.groupby(maestra_df['fecha_tarea_empleado'].dt.date).size()

# Crear gráfico de línea
plt.figure(figsize=(12, 6))
plt.plot(tareas_por_fecha.index, tareas_por_fecha.values, marker='o', linestyle='-', linewidth=1.5)

# Títulos y etiquetas
plt.title('Tareas en el tiempo hechas por el empleado', fontsize=14)
plt.xlabel('Fecha de tarea', fontsize=12)
plt.ylabel('Número de tareas', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# Se observa que desde el 2020, las tareas realizadas por el empleado van en aumento en los diferentes proyectos en el que participa. Este aumento de tareas puede deberse a una mayor demanda de proyectos en las diferentes compañias. En el 2025 tiene su pico maximo y luego, se presenta una bajada repentina. Puede deberse a falta d einformacion para el año 2025 en adelante

# %% [markdown]
# ## creacion_proyecto_grizzly

# %%
# Agrupar por fecha (día) y contar número de proyectos creados
proyectos_por_fecha = (maestra_df.groupby('proyecto_id')['creacion_proyecto_grizzly'].max().reset_index())



# Agrupar por fecha (día) y contar número de proyectos creados
proyectos_por_fecha = proyectos_por_fecha.groupby(proyectos_por_fecha['creacion_proyecto_grizzly'].dt.date).size()

# Crear gráfico de línea
plt.figure(figsize=(12, 6))
plt.plot(proyectos_por_fecha.index, proyectos_por_fecha.values, color='orange', marker='o', linestyle='-', linewidth=1.5)

# Títulos y etiquetas
plt.title('Evolución de creación de proyectos', fontsize=14)
plt.xlabel('Fecha de creación del proyecto', fontsize=12)
plt.ylabel('Número de proyectos creados', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# Al igual que las tareas en el tiempo, los proyectos en el tiempo tienden a aumentar.

# %% [markdown]
# ## duracion_meses_team

# %%
# Agrupar por team_id y tomar la duración máxima
max_duracion_por_team = (
    maestra_df.groupby('team_id')['duracion_meses_team']
    .max()
    .reset_index()
)

plt.figure(figsize=(8, 5))
plt.boxplot(max_duracion_por_team['duracion_meses_team'].dropna(), vert=True, patch_artist=True)

plt.title('Distribución de la duración (en meses) por equipo', fontsize=14)
plt.ylabel('Duración en meses', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
max_duracion_por_team['duracion_meses_team'].describe()
# Out:
# count   849.00
# mean     10.57
# std       8.32
# min       2.00
# 25%       7.00
# 50%       7.00
# 75%      11.00
# max      53.00
# Name: duracion_meses_team, dtype: float64

# %% [markdown]
# Mean = 10.57 meses → duracion promedio teams
#
# Q1 (25%) = 7 → El 25% de duracion de los teams es igual a 7 meses o menos
# Q2 (50%, mediana) = 7 → El 50%  de duracion de los teams es igual a 7 meses o menos
# Q3 (75%) = 11 → El 75% de duracion de los teams es igual a 11 meses o menos
# Rango intercuartílico (IQR):
#
# IQR= Q3 - Q1 = 4
# Límite inferior = Q1 - 1.5 × IQR  = 1
# Límite superior = Q3 + 1.5 × IQR  = 17
# Entonces, teams que su duracion es mayor a 17 meses son estadisticamente valores atipicos pero en este contexto no necesariamente porque pueden existir proyectos que por su naturaleza requieren un alto tiempo de realizacion como proyectos de infraestructura y plataforma de datos, proyectos de integracion y gobierno de datos, entre otros

# %% [markdown]
# ## estado

# %%
# Agrupación por proyecto y estado más reciente
estado_por_projecto = maestra_df.groupby(['proyecto_id'])[['fecha_registro_grizzly_empleado', 'estado']].max()

# Frecuencia normalizada
datos = estado_por_projecto["estado"].value_counts(normalize=True, dropna=False)

# Crear gráfico de pastel
plt.figure(figsize=(8, 8))
plt.pie(
    datos,
    labels=None,               # quitamos las etiquetas del gráfico
    autopct='%1.1f%%',
    startangle=90,
    counterclock=False
)

# Leyenda al costado derecho
plt.legend(
    labels=datos.index,
    title="Estado",
    bbox_to_anchor=(1.05, 0.5),  # posición (x, y)
    loc='center left'
)

plt.title('Distribución de estados de proyectos', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# La mayoria de proyectos estan activos con cerca de un 70%. Lo que nos indica que es grizzly es una herramienta con uso continuo. asimismo, un 2% de proyectos estan pendientes lo que podría indicar problemas de adopción inicial del producto.

# %% [markdown]
# # Analisis Bivariado

# %%
maestra_df.dtypes
# Out:
# tarea_id                                              object
# creacion_tarea_grizzly                   datetime64[ns, UTC]
# is_subtarea                                           object
# parent_id                                             object
# proyecto_id                                           object
# duracion_planeada_tarea                              float64
# duracion_trascurrida_tarea                           float64
# id_registro_declaracion                               object
# fecha_registro_grizzly_empleado          datetime64[ns, UTC]
# fecha_tarea_empleado                          datetime64[ns]
# duracion_tarea                                       float64
# fuente                                                object
# empleado_id                                           object
# creacion_proyecto_grizzly                datetime64[ns, UTC]
# team_id                                               object
# ...

# %%
# bivariado
# duracion planeada tarea vs duracion tareas
# duracion planeada projecto vs duracion projecto
# cantidad proyectos por equipo --> tabla de frecuencias
# consideration---> source dos categorias: correos - (existentes en grizzly)  ||| campo categoria (categoria="api") incluirlo en la API a diseñar
